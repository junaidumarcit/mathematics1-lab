# %% [markdown]
# 3x-y+2z=1,x+2y-z=3,2x-2y+4z=2

# %%
f1=lambda x,y,z:(1+y-2*z)/3
f2=lambda x,y,z:(3-x+z)/2
f3=lambda x,y,z:(2-2*x+2*y)/4
x0=0
y0=0
z0=0
count=1
e=float(input('enter tolerable error:'))
print('\ncount\tx\ty\tz\n')
condition=True
while condition:
  x1=f1(x0,y0,z0)
  y1=f2(x1,y0,z0)
  z1=f3(x1,y1,z0)
  print('%d\t%0.4f\t%0.4f\t%0.4f\n'%(count,x1,y1,z1))
  e1=abs(x0-y1);
  e2=abs(y0-y1);
  e3=abs(z0-z1);
  count+=1
  x0=x1
  y0=y1
  z0=z1
  condition=e1>e and e2>e and e3>e
print('\nsolution:x=%0.3f,y=%0.3f,z=%0.3f\n'%(x1,y1,z1))
# Out:
# enter tolerable error:0.0001
#
# count	x	y	z
#
# 1	0.3333	1.3333	1.0000
#
# 2	0.1111	1.9444	1.4167
#
# 3	0.0370	2.1898	1.5764
#
# 4	0.0123	2.2820	1.6348
#
# 5	0.0041	2.3154	1.6556
#
# 6	0.0014	2.3271	1.6629
#
# 7	0.0005	2.3312	1.6654
#
# 8	0.0002	2.3326	1.6662
#
# 9	0.0001	2.3331	1.6665
#
# 10	0.0000	2.3333	1.6666
#
#
# solution:x=0.000,y=2.333,z=1.667

# %% [markdown]
# 20x+y-2z=17,3x+20y-z=-18,2x-3y+20z=25

# %%
f1=lambda x,y,z:(17-y+2*z)/20
f2=lambda x,y,z:(-18+z-3*x)/20
f3=lambda x,y,z:(25-2*x+3*y)/20
x0=0
y0=0
z0=0
count=1
e=float(input('enter tolerable error:'))
print('\ncount\tx\ty\tz\n')
condition=True
while condition:
  x1=f1(x0,y0,z0)
  y1=f2(x1,y0,z0)
  z1=f3(x1,y1,z0)
  print('%d\t%0.4f\t%0.4f\t%0.4f\n'%(count,x1,y1,z1))
  e1=abs(x0-y1);
  e2=abs(y0-y1);
  e3=abs(z0-z1);
  count+=1
  x0=x1
  y0=y1
  z0=z1
  condition=e1>e and e2>e and e3>e
print('\nsolution:x=%0.3f,y=%0.3f,z=%0.3f\n'%(x1,y1,z1))
# Out:
# enter tolerable error:0.0001
#
# count	x	y	z
#
# 1	0.8500	-1.0275	1.0109
#
# 2	1.0025	-0.9998	0.9998
#
# 3	1.0000	-1.0000	1.0000
#
# 4	1.0000	-1.0000	1.0000
#
#
# solution:x=1.000,y=-1.000,z=1.000

# %% [markdown]
# 83x+11y-4z=95,7x+52y+13z=104,3x+8y+29z=71

# %%
f1=lambda x,y,z:(95-11*y+4*z)/83
f2=lambda x,y,z:(104-7*x-13*z)/52
f3=lambda x,y,z:(71-8*y-3*x)/29
x0=0
y0=0
z0=0
count=1
e=float(input('enter tolerable error:'))
print('\ncount\tx\ty\tz\n')
condition=True
while condition:
  x1=f1(x0,y0,z0)
  y1=f2(x1,y0,z0)
  z1=f3(x1,y1,z0)
  print('%d\t%0.4f\t%0.4f\t%0.4f\n'%(count,x1,y1,z1))
  e1=abs(x0-y1);
  e2=abs(y0-y1);
  e3=abs(z0-z1);
  count+=1
  x0=x1
  y0=y1
  z0=z1
  condition=e1>e and e2>e and e3>e
print('\nsolution:x=%0.3f,y=%0.3f,z=%0.3f\n'%(x1,y1,z1))
# Out:
# enter tolerable error:0.00001
#
# count	x	y	z
#
# 1	1.1446	1.8459	1.8207
#
# 2	0.9877	1.4119	1.9566
#
# 3	1.0518	1.3693	1.9617
#
# 4	1.0577	1.3672	1.9617
#
# 5	1.0579	1.3672	1.9617
#
# 6	1.0579	1.3672	1.9617
#
#
# solution:x=1.058,y=1.367,z=1.962
